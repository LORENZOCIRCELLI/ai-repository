# %%
import torch
import numpy as np

# %%
data = [[1, 2],[3, 4]]
x_data = torch.tensor(data)

# %%
np_array = np.array(data)
x_np = torch.from_numpy(np_array)

# %%
x_ones = torch.ones_like(x_data) # retains the properties of x_data
print(f"Ones Tensor: \n {x_ones} \n")

x_rand = torch.rand_like(x_data, dtype=torch.int16) # overrides the datatype of x_data
print(f"Random Tensor: \n {x_rand} \n")
# Out:
# Ones Tensor:
#  tensor([[1, 1],
#         [1, 1]])
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[6], line 4
#       1 x_ones = torch.ones_like(x_data) # retains the properties of x_data
#       2 print(f"Ones Tensor: \n {x_ones} \n")
# ----> 4 x_rand = torch.rand_like(x_data, dtype=torch.int16) # overrides the datatype of x_data
#       5 print(f"Random Tensor: \n {x_rand} \n")
#
# NotImplementedError: "check_uniform_bounds" not implemented for 'Short'
